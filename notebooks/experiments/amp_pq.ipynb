# %%
import sys
import git
import pathlib

# Set up the PROJ_ROOT variable
PROJ_ROOT_PATH = pathlib.Path(git.Repo('.', search_parent_directories=True).working_tree_dir)
PROJ_ROOT =  str(PROJ_ROOT_PATH)
if PROJ_ROOT not in sys.path:
    sys.path.append(PROJ_ROOT)

# Explicitly add the current notebook's directory
CURRENT_DIR = str(pathlib.Path().absolute())
if CURRENT_DIR not in sys.path:
    sys.path.insert(0, CURRENT_DIR)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors
# %matplotlib inline  
# Set the float display format to scientific notation
pd.set_option('display.float_format', '{:.2e}'.format)
# pd.set_option('display.float_format', '{:.2f}'.format)
# pd.set_option('display.precision', 2)

import yaml

# %%
# fridge = "xld1000sl"
fridge = "kide"

# %%
# exp = "ff-fc-delft-"+ amp + "_" + wire + "-" + fridge
# fname = PROJ_ROOT_PATH / "notebooks" / "experiments" / fridge / amp / exp / f"{exp}.pkl"
# pqfname =  PROJ_ROOT_PATH / "notebooks" / "experiments" / fridge / amp / exp  / f"PQ_{exp}.pkl"
# df =  pd.read_pickle(pqfname)
# min_value = df.loc["PQ"].min()
# min_column = df.loc["PQ"].idxmin()

# %%
def get_pq(fridge, amp, wire):
    exp = "ff-fc-delft-"+ amp + "_" + wire + "-" + fridge
    fname = PROJ_ROOT_PATH / "notebooks" / "experiments" / fridge / amp / exp / f"{exp}.pkl"
    pqfname =  PROJ_ROOT_PATH / "notebooks" / "experiments" / fridge / amp / exp  / f"PQ_{exp}.pkl"
    df =  pd.read_pickle(pqfname)
    min_value = df.loc["PQ"].min()
    min_column = df.loc["PQ"].idxmin()
    return min_value, min_column

# %%
amps  = ["hemt", "hemt-lp", "hemt-ulp", "sisv1" ]
wires = ["cu", "mn", "ybco"]

data = {}
for amp in amps:
    row = {}
    for wire in wires:
        min_value, min_column = get_pq(fridge, amp, wire)
        row[wire] = (f"{min_value}")
        # row[wire] = (f"{min_value} ({min_column})")
    data[amp] = row

df_amp = pd.DataFrame.from_dict(data, orient="index")
df_amp.index.name = "Amplifier"
df_amp.columns.name = "Wire"

# %%
df_amp
# Out:
# Wire        cu    mn  ybco
# Amplifier
# hemt       616  1696  1768
# hemt-lp    760  3872  3952
# hemt-ulp   424  3864  4016
# sisv1      496  3288  4152
