# %%
from qiskit_ibm_runtime import __version__
print(__version__)  # 0.30.0

# get the backend instance
from qiskit_ibm_runtime import QiskitRuntimeService
service = QiskitRuntimeService()
ibmq_manila = service.backend('ibmq_manila')

# fetch properties
from datetime import datetime

when = datetime(day=15, month=4, year=2023)  # April 15th, 2023
properties_20230415 = ibmq_manila.properties(datetime=when)

print(properties_20230415.last_update_date)  # 2023-04-14 22:46:47+02:00
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from qiskit_ibm_runtime import __version__
#       2 print(__version__)  # 0.30.0
#       4 # get the backend instance
#
# ModuleNotFoundError: No module named 'qiskit_ibm_runtime'
